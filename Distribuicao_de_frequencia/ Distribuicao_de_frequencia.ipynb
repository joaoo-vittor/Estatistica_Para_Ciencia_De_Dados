# %% [markdown]
# # Distribuição de frequência
# ---------------

# %% [markdown]
# ### Distribuição de frequência - teoria

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# ![5.png](data:image/png;base64,...)

# %% [markdown]
# ![7.png](data:image/png;base64,...)

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ### Distribuição de frequência - implementação

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
dados = np.array([160, 165, 167, 164, 160, 166, 160, 161, 150, 152, 173, 160, 155,
                  164, 168, 162, 161, 168, 163, 156, 155, 169, 151, 170, 164,
                  155, 152, 163, 160, 155, 157, 156, 158, 158, 161, 154, 161, 156, 172, 153])

# %%
dados = np.sort(dados)

# %%
dados
# Out:
# array([150, 151, 152, 152, 153, 154, 155, 155, 155, 155, 156, 156, 156,
#        157, 158, 158, 160, 160, 160, 160, 160, 161, 161, 161, 161, 162,
#        163, 163, 164, 164, 164, 165, 166, 167, 168, 168, 169, 170, 172,
#        173])

# %%
minimo = dados.min()
minimo
# Out:
# 150

# %%
maximo = dados.max()
maximo
# Out:
# 173

# %%
np.unique(dados, return_counts=True)
# Out:
# (array([150, 151, 152, 153, 154, 155, 156, 157, 158, 160, 161, 162, 163,
#         164, 165, 166, 167, 168, 169, 170, 172, 173]),
#  array([1, 1, 2, 1, 1, 4, 3, 1, 2, 5, 4, 1, 2, 3, 1, 1, 1, 2, 1, 1, 1, 1]))

# %%
plt.bar(dados, dados)
plt.show()

# %% [markdown]
# #### Numero de classes
#
# - i = 1 + 3.3 * log n

# %%
n = len(dados)
n
# Out:
# 40

# %%
i = 1 + 3.3 * np.log10(n)

# %%
i = round(i)
i
# Out:
# 6

# %% [markdown]
# #### Amplitude do intervalo
#
# - h = AA / i
#
# - AA = Xmax - Xmin

# %%
AA = maximo - minimo
AA
# Out:
# 23

# %%
h = AA / i
h
# Out:
# 3.8333333333333335

# %%
import math

# %%
h = math.ceil(h)
h
# Out:
# 4

# %% [markdown]
# #### Construção da distribuição de frequência

# %%
intervalos = np.arange(minimo, maximo + 2, step=h)
intervalos
# Out:
# array([150, 154, 158, 162, 166, 170, 174])

# %%
intervalo1, intervalo2, intervalo3, intervalo4, intervalo5, intervalo6 = 0,0,0,0,0,0

for i in range(n):
  if dados[i] >= intervalos[0] and dados[i] < intervalos[1]:
    intervalo1 += 1
  elif dados[i] >= intervalos[1] and dados[i] < intervalos[2]:
    intervalo2 += 1
  elif dados[i] >= intervalos[2] and dados[i] < intervalos[3]:
    intervalo3 += 1
  elif dados[i] >= intervalos[3] and dados[i] < intervalos[4]:
    intervalo4 += 1
  elif dados[i] >= intervalos[4] and dados[i] < intervalos[5]:
    intervalo5 += 1
  elif dados[i] >= intervalos[5] and dados[i] < intervalos[6]:
    intervalo6 += 1

# %%
lista_intervalos = []
lista_intervalos.append(intervalo1)
lista_intervalos.append(intervalo2)
lista_intervalos.append(intervalo3)
lista_intervalos.append(intervalo4)
lista_intervalos.append(intervalo5)
lista_intervalos.append(intervalo6)

# %%
lista_intervalos
# Out:
# [5, 9, 11, 7, 5, 3]

# %%
lista_classes = []

for i in range(len(lista_intervalos)):
  lista_classes.append(f'{intervalos[i]} - {intervalos[i+1]}')
lista_classes
# Out:
# ['150 - 154', '154 - 158', '158 - 162', '162 - 166', '166 - 170', '170 - 174']

# %%
plt.subplots(figsize=(8,6))
plt.bar(lista_classes, lista_intervalos)
plt.title('Distribuição de frequência - histograma')
plt.xlabel('Intervalos')
plt.ylabel('Valores');

# %% [markdown]
# ### Distribuição de frequência e Histograma com numpy e matplotlib

# %%
dados = np.array([160, 165, 167, 164, 160, 166, 160, 161, 150, 152, 173, 160, 155,
                  164, 168, 162, 161, 168, 163, 156, 155, 169, 151, 170, 164,
                  155, 152, 163, 160, 155, 157, 156, 158, 158, 161, 154, 161, 156, 172, 153])

# %%
frequencia, classes = np.histogram(dados)

# %%
frequencia, classes, len(classes)
# Out:
# (array([4, 2, 7, 3, 9, 3, 5, 3, 2, 2]),
#  array([150. , 152.3, 154.6, 156.9, 159.2, 161.5, 163.8, 166.1, 168.4,
#         170.7, 173. ]),
#  11)

# %%
plt.hist(dados, bins=classes);

# %%
frequencia, classes = np.histogram(dados, bins=5)
frequencia, classes
# Out:
# (array([ 6, 10, 12,  8,  4]),
#  array([150. , 154.6, 159.2, 163.8, 168.4, 173. ]))

# %%
plt.hist(dados, bins=5);

# %%
frequencia, classes = np.histogram(dados, bins='sturges')
frequencia, classes
# Out:
# (array([ 5,  8,  3, 12,  5,  4,  3]),
#  array([150.        , 153.28571429, 156.57142857, 159.85714286,
#         163.14285714, 166.42857143, 169.71428571, 173.        ]))

# %%
plt.hist(dados, classes);

# %% [markdown]
# ### Distribuição de frequência e Histograma com pandas e seaborn

# %%
dataset =  pd.DataFrame({'dados': dados})

# %%
dataset.head()
# Out:
#    dados
# 0    160
# 1    165
# 2    167
# 3    164
# 4    160

# %%
dataset.plot.hist();

# %%
sns.displot(dados, kind='hist');

# %%
sns.histplot(dados, kde=True);

# %% [markdown]
# ### EXERCÍCIO

# %%
path = '/content/drive/MyDrive/Estatistica_Para_Ciencia_De_Dados/Bases de dados/census.csv'

# %%
dataset_census = pd.read_csv(path)

# %%
dataset_census.head(3)
# Out:
#    age          workclass  final-weight  ... hour-per-week  native-country  income
# 0   39          State-gov         77516  ...            40   United-States   <=50K
# 1   50   Self-emp-not-inc         83311  ...            13   United-States   <=50K
# 2   38            Private        215646  ...            40   United-States   <=50K
#
# [3 rows x 15 columns]

# %%
dataset_census['age'].max(), dataset_census['age'].min()
# Out:
# (90, 17)

# %%
dataset_census['age'].plot.hist(bins=10);

# %%
dataset_census['age'] = pd.cut(dataset_census['age'], bins=[0, 17, 25, 40, 60, 90],
                               labels=['faixa1', 'faixa2', 'faixa3', 'faixa4', 'faixa5'])

# %%
dataset_census.head(3)
# Out:
#       age          workclass  ...  native-country  income
# 0  faixa3          State-gov  ...   United-States   <=50K
# 1  faixa4   Self-emp-not-inc  ...   United-States   <=50K
# 2  faixa3            Private  ...   United-States   <=50K
#
# [3 rows x 15 columns]

# %%
dataset_census['age'].unique()
# Out:
# ['faixa3', 'faixa4', 'faixa2', 'faixa5', 'faixa1']
# Categories (5, object): ['faixa1' < 'faixa2' < 'faixa3' < 'faixa4' < 'faixa5']

# %%
plt.subplots(figsize=(8,6))
sns.histplot(dataset_census['age']);

# %% [markdown]
# ### Introdução a regras de associação

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# ### Regras de associação com Apriori

# %%
dataset_census.head(3)
# Out:
#       age          workclass  ...  native-country  income
# 0  faixa3          State-gov  ...   United-States   <=50K
# 1  faixa4   Self-emp-not-inc  ...   United-States   <=50K
# 2  faixa3            Private  ...   United-States   <=50K
#
# [3 rows x 15 columns]

# %%
dataset_apriori = dataset_census[['age', 'workclass', 'education', 'marital-status',
                                  'relationship', 'occupation', 'sex', 'native-country',
                                  'income']]

# %%
dataset_apriori.head(3)
# Out:
#       age          workclass   education  ...    sex  native-country  income
# 0  faixa3          State-gov   Bachelors  ...   Male   United-States   <=50K
# 1  faixa4   Self-emp-not-inc   Bachelors  ...   Male   United-States   <=50K
# 2  faixa3            Private     HS-grad  ...   Male   United-States   <=50K
#
# [3 rows x 9 columns]

# %%
dataset_apriori.shape
# Out:
# (32561, 9)

# %%
dataset_apriori = dataset_apriori.sample(n=1000)
dataset_apriori.shape
# Out:
# (1000, 9)

# %%
transacoes = []

for i in range(dataset_apriori.shape[0]):
  transacoes.append([str(dataset_apriori.values[i, j]) for j in range(dataset_apriori.shape[1])])

# %%
len(transacoes)
# Out:
# 1000

# %%
transacoes[1]
# Out:
# ['faixa4',
#  ' Private',
#  ' Some-college',
#  ' Married-civ-spouse',
#  ' Husband',
#  ' Craft-repair',
#  ' Male',
#  ' United-States',
#  ' >50K']

# %%
# !pip install apyori
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-cp37-none-any.whl size=5975 sha256=5d40b60f443d1b7475ce2c163994a816c9ee22d30489c03fa5e0f4a48f333160
#   Stored in directory: /root/.cache/pip/wheels/5d/92/bb/474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# ...

# %%
from apyori import apriori

# %%
regras = apriori(transacoes, min_support=0.3, min_confidence=0.2)

# %%
resultados = list(regras)

# %%
len(resultados)
# Out:
# 37

# %%
resultados
# Out:
# [RelationRecord(items=frozenset({' <=50K'}), support=0.761, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' <=50K'}), confidence=0.761, lift=1.0)]),
#  RelationRecord(items=frozenset({' Female'}), support=0.328, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Female'}), confidence=0.328, lift=1.0)]),
#  RelationRecord(items=frozenset({' HS-grad'}), support=0.335, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' HS-grad'}), confidence=0.335, lift=1.0)]),
#  RelationRecord(items=frozenset({' Husband'}), support=0.412, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Husband'}), confidence=0.412, lift=1.0)]),
#  RelationRecord(items=frozenset({' Male'}), support=0.672, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Male'}), confidence=0.672, lift=1.0)]),
# ...

# %%
resultados[11]
# Out:
# RelationRecord(items=frozenset({' Male', ' <=50K'}), support=0.465, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({' Male', ' <=50K'}), confidence=0.465, lift=1.0), OrderedStatistic(items_base=frozenset({' <=50K'}), items_add=frozenset({' Male'}), confidence=0.6110381077529566, lift=0.9092828984418997), OrderedStatistic(items_base=frozenset({' Male'}), items_add=frozenset({' <=50K'}), confidence=0.6919642857142857, lift=0.9092828984418997)])
